# %%
from feature_extracting import plot_keypress, detect_keypress, cut_peak, ste
import soundfile as sf

# %%
plot_keypress('./dataset/space_1.wav', True)

# %%
y, sampling_rate = sf.read('./dataset/space_2.wav')
a = detect_keypress(y, sampling_rate)
sampling_rate
# Out:
# 44100

# %%
a
# Out:
# array([-0.00115967, -0.0010376 , -0.00109863, ...,  0.00466919,
#         0.00402832,  0.003479  ], shape=(4851,))

# %%
y, sampling_rate = sf.read('./dataset/space_1.wav')
a = cut_peak(y, sampling_rate)
a
# Out:
# array([0.00134277, 0.0012207 , 0.0012207 , ..., 0.        , 0.00201416,
#        0.00576782], shape=(2048,))

# %%
y, sampling_rate = sf.read('./dataset/h_1.wav')
a = cut_peak(y, sampling_rate)
a
# Out:
# array([-2.74658203e-04, -6.10351562e-05, -6.10351562e-05, ...,
#        -5.00488281e-03, -4.11987305e-03, -6.34765625e-03], shape=(2048,))

# %%
y, sampling_rate = sf.read('./dataset/space_1.wav')
ste(y, sampling_rate, window_ms = 20, shift_ms = 10, smooth = False, visualize = True)
# Out:
# array([1.85333192e-07, 1.86264515e-07, 1.80676579e-07, 1.99303031e-07,
#        2.06753612e-07, 1.99303031e-07, 1.95577741e-07, 1.74157321e-07,
#        1.68569386e-07, 1.89989805e-07, 1.76019967e-07, 1.76019967e-07,
#        2.03028321e-07, 2.01165676e-07, 2.06753612e-07, 1.99303031e-07,
#        1.77882612e-07, 1.65775418e-07, 1.89058483e-07, 1.84401870e-07,
#        1.73225999e-07, 1.92783773e-07, 2.00234354e-07, 2.03959644e-07,
#        2.03028321e-07, 1.94646418e-07, 1.65775418e-07, 1.76019967e-07,
#        1.89058483e-07, 1.81607902e-07, 1.89058483e-07, 2.00234354e-07,
#        2.02096999e-07, 1.96509063e-07, 2.59550288e-04, 5.99836931e-04,
#        1.77955434e+00, 2.52952123e+00, 8.09789979e-01, 9.29438947e-02,
#        4.04954571e-02, 1.47302123e-02, 1.24633489e-02, 6.31959923e-03,
#        3.54079437e-03, 4.10892349e-03, 4.47829999e-03, 5.97502394e-02,
#        7.68943224e-02, 2.59015635e-02, 8.32478609e-03, 3.02956812e-03,
# ...

# %%
y, sampling_rate = sf.read('test3.wav')
ste(y, sampling_rate, window_ms = 20, shift_ms = 10, smooth = False, visualize = True)
# Out:
# array([1.85333192e-07, 1.86264515e-07, 1.80676579e-07, 1.99303031e-07,
#        2.06753612e-07, 1.99303031e-07, 1.95577741e-07, 1.74157321e-07,
#        1.68569386e-07, 1.89989805e-07, 1.76019967e-07, 1.76019967e-07,
#        2.03028321e-07, 2.01165676e-07, 2.06753612e-07, 1.99303031e-07,
#        1.77882612e-07, 1.65775418e-07, 1.89058483e-07, 1.84401870e-07,
#        1.73225999e-07, 1.92783773e-07, 2.00234354e-07, 2.03959644e-07,
#        2.03028321e-07, 1.94646418e-07, 1.65775418e-07, 1.76019967e-07,
#        1.89058483e-07, 1.81607902e-07, 1.89058483e-07, 2.00234354e-07,
#        2.02096999e-07, 1.96509063e-07, 1.60908327e-04, 3.31278890e-04,
#        2.60054134e-04, 5.90944663e-04, 6.71553425e-04, 4.30684537e-04,
#        4.42960300e-04, 6.13803975e-04, 6.53830357e-04, 5.28179109e-04,
#        7.21906312e-04, 1.03415921e-03, 6.88015483e-04, 1.97011977e-04,
#        2.47343443e-04, 4.19265591e-04, 4.13679518e-04, 2.32468359e-04,
# ...

# %%
import pandas as pd
df = pd.read_csv('dataset.csv')

# %%
df
# Out:
#      feature_1  feature_2  feature_3  feature_4  feature_5  feature_6  \
# 0     0.473584  -0.346465   1.000000   0.788270   0.617821  -0.347031
# 1     1.000000  -0.357812   0.063167   0.194370  -0.306994  -0.546941
# 2     0.598263  -0.061163   0.844944   1.000000   0.316974  -0.329623
# 3     1.000000  -0.575523  -0.315870  -0.055769  -0.209354  -0.642863
# 4     0.818773  -0.370962  -0.057763   1.000000   0.709620  -0.553092
# ..         ...        ...        ...        ...        ...        ...
# 592  -0.584870  -0.654955  -0.571751  -0.663877  -0.164915  -0.530996
# 593  -0.298330  -0.644658  -0.187549   0.233958   0.074076  -0.110866
# 594   1.000000  -0.599479  -0.281627   0.012468  -0.442477  -0.465733
# 595   0.413210  -0.682496  -0.284846   0.377954   0.375729   0.442661
# 596  -0.033599  -0.263965  -0.043876   0.623838   0.230988   0.009361
#
#      feature_7  feature_8  feature_9  feature_10  ...  feature_1016  \
# ...

# %%
from feature_extracting import extract_mfcc

df = extract_mfcc(df)
